# %%
import pandas as pd
import json

# %%
with open('dataset/2021-03-17_classification-labeling-results.json') as json_file:
    data = json.load(json_file)
    for task in data:
        print('image:', task['image'])
        print('possible_answers: ',task['possible_answers'])
        for label_result in task['selected_labels']:
            print('result_id: ',label_result['result_id'], ' -- selected label: ', label_result['coa_description'])
    
        print('-----')
# Out:
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_4.jpg
# possible_answers:  B O cross potenty fitchy<|> eagle :dim: semy of fleurs-de-lis  {OS, BO}<|>B O 3 crowns<|>A S dragon<|>O GAA lion enthroned holding sword
# result_id:  1  -- selected label:  B O cross potenty fitchy
# result_id:  3  -- selected label:  B O 3 crowns
# result_id:  5  -- selected label:  O GAA lion enthroned holding sword
# result_id:  4  -- selected label:  A S dragon
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_8.jpg
# possible_answers:  O G rose<|>G A 3 hares salient<|> lion; 2 bars embattled-counterembattled; = ; =  {AG, GA}<|>A G 2 bars radiant
# result_id:  3  -- selected label:   lion; 2 bars embattled-counterembattled; = ; =  {AG, GA}
# result_id:  1  -- selected label:  O G rose
# result_id:  2  -- selected label:  G A 3 hares salient
# result_id:  4  -- selected label:  A G 2 bars radiant
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_9.jpg
# possible_answers:  B AOG elephant bearing tower above crown in base<|>O GO lion guard ch. cross<|>S A saltire<|>G A 3 fish naiant in pale<|>A O stag
# result_id:  1  -- selected label:  B AOG elephant bearing tower above crown in base
# result_id:  2  -- selected label:  O GO lion guard ch. cross
# result_id:  5  -- selected label:  A O stag
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_10.jpg
# possible_answers:  B O 3 fleurs-de-lis
# result_id:  1  -- selected label:  B O 3 fleurs-de-lis
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_11.jpg
# possible_answers:   castle; lion; =; =  {GO, AP}<|>O G 4 pales<|> cross of Jerusalem; barry & lion cr.; lion cr.; lion   {AO, XG-AB, AG, GO}<|> pf[pp[barruly; semy of fleurs-de-lis & label; cross of Jerusalem]; pp[semy of fleurs-de-lis & border; 2 barbels addorsed, crusily; bend ch. 3 eagles]]   {AG, BOG, AO; BOG, BOO, OGA; 3:3}<|> Navarre chain; semy of fleurs-de-lis & bend compony; =; =   {GO, BOAG}
# result_id:  1  -- selected label:   castle; lion; =; =  {GO, AP}
# result_id:  2  -- selected label:  O G 4 pales
# result_id:  3  -- selected label:   cross of Jerusalem; barry & lion cr.; lion cr.; lion   {AO, XG-AB, AG, GO}
# result_id:  5  -- selected label:   Navarre chain; semy of fleurs-de-lis & bend compony; =; =   {GO, BOAG}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_12.jpg
# possible_answers:   cross of Lorraine on mount; barry; =; =   {GAV, GA}
# result_id:  1  -- selected label:   cross of Lorraine on mount; barry; =; =   {GAV, GA}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_13.jpg
# possible_answers:   man cr. holding sword; bend; =; =   {AGN, GA}<|>G A 3 lion's heads cr.<|>G OA arm holding dagger isst sn
# result_id:  2  -- selected label:  G A 3 lion's heads cr.
# result_id:  3  -- selected label:  G OA arm holding dagger isst sn
# result_id:  1  -- selected label:   man cr. holding sword; bend; =; =   {AGN, GA}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_14.jpg
# possible_answers:  B OO serpent engorging orb<|>A S bendy<|>B NS monster as an old man's head betw 2 eagle's claws winged<|>A G pily-barry<|> 2 crescents doubled and vyvern's head isst; 2 crescents addorsed acc. cross in chf; =; =   {AOS, GAA}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_16.jpg
# possible_answers:   3 fleurs-de-lis & border compony; pp[bendy & border; lion]; pp[bendy & border; lion q.f. cr.]; = :E: lion  {BOG; OBG, AG; SO; OS}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_17.jpg
# possible_answers:   semy of fleurs-de-lis; dolphin; = ; =    {BO, OB}<|> 3 fleurs-de-lis & border compony; bendy & border; =; =  :E: lion  {BO-AG, OBG, OS}<|> semy of fleurs-de-lis & border compony; lion; lion q.f. cr.; =   {BOAG, SO, AG}<|>B OG 3 fleurs-de-lis & label
# result_id:  4  -- selected label:  B OG 3 fleurs-de-lis & label
# result_id:  3  -- selected label:   semy of fleurs-de-lis & border compony; lion; lion q.f. cr.; =   {BOAG, SO, AG}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_18.jpg
# possible_answers:  B OG semy of fleurs-de-lis & border engrailed<|>B OA 3 fleurs-de-lis & border<|>B OG 3 fleurs-de-lis & bend<|>- ILLEGIBLE
# result_id:  1  -- selected label:  B OG semy of fleurs-de-lis & border engrailed
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_19.jpg
# possible_answers:   2 barbels addorsed, crusily; 3 fleurs-de-lis & border; =; = :E: bend ch. 3 eagles   {BOO, BOG, OGA}
# result_id:  1  -- selected label:   2 barbels addorsed, crusily; 3 fleurs-de-lis & border; =; = :E: bend ch. 3 eagles   {BOO, BOG, OGA}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_20.jpg
# possible_answers:  G OS bend ch. mullet<|>O B bugle-horn stringed<|>O S lion rampant<|>G E chevron<|>A S 3 lions
# result_id:  1  -- selected label:  G OS bend ch. mullet
# result_id:  2  -- selected label:  O B bugle-horn stringed
# result_id:  3  -- selected label:  O S lion rampant
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_21.jpg
# possible_answers:  B OO cross & border<|> bend; eagle; =; =  {GA, GO}<|>B AO lion cr., crusily<|>O G+ cross & canton {Ar lion Sa}<|>O BG bendy & border engrailed
# result_id:  2  -- selected label:   bend; eagle; =; =  {GA, GO}
# result_id:  1  -- selected label:  B OO cross & border
# result_id:  3  -- selected label:  B AO lion cr., crusily
# result_id:  4  -- selected label:  O G+ cross & canton {Ar lion Sa}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_22.jpg
# possible_answers:  A B chief<|> eagle & border; pale ch. 3 chevrons; =; =   {OGZ, OGA}<|>A G hare stat.<|>- CREST only<|>- CREST only
# result_id:  2  -- selected label:   eagle & border; pale ch. 3 chevrons; =; =   {OGZ, OGA}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_23.jpg
# possible_answers:  E G griffin segreant<|>B A+ 3 lozenges in fess ch. escutch {Az 3 lozenges in fess Ar}<|>A GOO chief ch. 2 roses & border<|>- CREST only<|>O G eagle
# result_id:  3  -- selected label:  A GOO chief ch. 2 roses & border
# result_id:  2  -- selected label:  B A+ 3 lozenges in fess ch. escutch {Az 3 lozenges in fess Ar}
# result_id:  5  -- selected label:  O G eagle
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_24.jpg
# possible_answers:   3 fleurs-de-lis; 3 lions passt guard; =; =  {BO, GO}
# result_id:  1  -- selected label:   3 fleurs-de-lis; 3 lions passt guard; =; =  {BO, GO}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_25.jpg
# possible_answers:   eagle ch. crescent; mounted knight holding scimitar; =; =   {GA, GA}<|>O B 3 lions passt guard<|>G OA lion holding axe<|> lion acc. double tressure flory-counterflory; man holding dish; =; =   {GOO, OGS}<|>O SGA per pale eagle isst & mailed arm holding sword
# result_id:  2  -- selected label:  O B 3 lions passt guard
# result_id:  3  -- selected label:  G OA lion holding axe
# result_id:  5  -- selected label:  O SGA per pale eagle isst & mailed arm holding sword
# result_id:  1  -- selected label:   eagle ch. crescent; mounted knight holding scimitar; =; =   {GA, GA}
# result_id:  4  -- selected label:   lion acc. double tressure flory-counterflory; man holding dish; =; =   {GOO, OGS}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_26.jpg
# possible_answers:  A +GO 5 quinas in saltire & border castely
# result_id:  1  -- selected label:  A +GO 5 quinas in saltire & border castely
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_27.jpg
# possible_answers:  G AB chief per pale & 3 mullets cch<|>O GAS saltire & border semy of  flanchis<|>B A 3 bends<|>A B 6 roundels (2:2:2)<|>O V 3 pears
# result_id:  5  -- selected label:  O V 3 pears
# result_id:  2  -- selected label:  O GAS saltire & border semy of  flanchis
# result_id:  4  -- selected label:  A B 6 roundels (2:2:2)
# result_id:  3  -- selected label:  B A 3 bends
# result_id:  1  -- selected label:  G AB chief per pale & 3 mullets cch
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_28.jpg
# possible_answers:   tower; bendy of 4; =; =   {OB, OB}<|>A G per saltire<|>O GX AG 3 bars & border checky<|> 5 fleurs-de-lis in saltire; cross flory ch. cross; =; =   {OG, GAG}<|>V ABA tower & border flory
# result_id:  1  -- selected label:   tower; bendy of 4; =; =   {OB, OB}
# result_id:  5  -- selected label:  V ABA tower & border flory
# result_id:  2  -- selected label:  A G per saltire
# result_id:  3  -- selected label:  O GX AG 3 bars & border checky
# result_id:  4  -- selected label:   5 fleurs-de-lis in saltire; cross flory ch. cross; =; =   {OG, GAG}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_29.jpg
# possible_answers:   ps[pp[paly; 2 cows]; cross ch. 5 escallops; =; pp[2 cows; paly]]    {OG, OG; OSA}<|> 2 pals; harp; =; =   {AG, GO}<|>O GB 3 bars & border<|>G O 5 towers (2:1:2)<|>E GO 3 pales & chief
# result_id:  2  -- selected label:   2 pals; harp; =; =   {AG, GO}
# result_id:  3  -- selected label:  O GB 3 bars & border
# result_id:  4  -- selected label:  G O 5 towers (2:1:2)
# result_id:  1  -- selected label:   ps[pp[paly; 2 cows]; cross ch. 5 escallops; =; pp[2 cows; paly]]    {OG, OG; OSA}
# result_id:  5  -- selected label:  E GO 3 pales & chief
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_30.jpg
# possible_answers:   eagle; serpent engorging child; =; =  {OS, ABG}
# result_id:  1  -- selected label:   eagle; serpent engorging child; =; =  {OS, ABG}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_31.jpg
# possible_answers:  G A branch with 3 oak leaves erect
# result_id:  1  -- selected label:  G A branch with 3 oak leaves erect
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_32.jpg
# possible_answers:  B A eagle
# result_id:  1  -- selected label:  B A eagle
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_33.jpg
# possible_answers:   3 fleurs-de-lis & border indented compony; eagle; =; =    {BOAG, BO}
# result_id:  1  -- selected label:   3 fleurs-de-lis & border indented compony; eagle; =; =    {BOAG, BO}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_34.jpg
# possible_answers:   barry; lion q.f.; =; =  {OS, GA}
# result_id:  1  -- selected label:   barry; lion q.f.; =; =  {OS, GA}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_36.jpg
# possible_answers:   cross; fess; =; =   {AS, OS}
# result_id:  1  -- selected label:   cross; fess; =; =   {AS, OS}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_38.jpg
# possible_answers:   wheel; pq[lion guard; lion; =; =]; =; =   {GA; GA, AG}
# result_id:  1  -- selected label:   wheel; pq[lion guard; lion; =; =]; =; =   {GA; GA, AG}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_44.jpg
# possible_answers:  O S 3 antlers in pale<|>O SV cock on mount<|>O GZ eagle & border<|>A S qtly<|>O GV doe on terrace
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_45.jpg
# possible_answers:  A G gonfanon<|>O GV doe on terrace<|>G OO bend betw 2 lions per bend<|>G OO bend betw 4 lions<|>O B bendy ch. semy of fleurs-de-lis cch
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_46.jpg
# possible_answers:  A S bend dancetty<|>O B 3 antlers in pale<|>G A gonfanon<|>A G gonfanon<|>A B 3 wings fesswise (2:1)
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_48.jpg
# possible_answers:  G AV elephant on terrasse<|>A SA woman holdig mitre<|>G A qtly<|>A G pily-paly<|>G A gonfanon
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_50.jpg
# possible_answers:  G O gonfanon<|>O S talbot gorged<|>G A chief<|>O G lion rampant<|>G OS pale ch. 3 chevrons
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_51.jpg
# possible_answers:  G A heron stat
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_52.jpg
# possible_answers:   antler (circular), antler (circular); =; =   {OG, OS}<|>B A 2 antlers in saltire<|>B A lion cr.<|>B A lion cr.<|>O SX AG saltire & border compony
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_53.jpg
# possible_answers:  O SG chicot per bend fruited
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_54.jpg
# possible_answers:  A G barry of 4<|>A G bendy of 4<|>G OB gem-ring<|>O G per pale<|>- ILLEGIBLE
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_56.jpg
# possible_answers:  O SA chief ch. mullet<|>S AO lion cr., billety<|>O B crequer plant with oak leaves<|>B O 4 chevrons<|>O BG fess betw 4 quarterfoils
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_57.jpg
# possible_answers:  B O 3 pinecones<|>O G fess
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_58.jpg
# possible_answers:  O G paly<|>A OA crown with eagle isst<|>B OO fretty & chief<|>A S talon winged<|>A O lion holding arrow piercing its head
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_60.jpg
# possible_answers:   elm leaf; crown; =; =   {BO, BO}<|>A BA bend ch. 3 fleurs-de-lis<|>G AO 2 elm trees per saltire & border<|>A S harpoon iron in bend<|>S AAG fretty & chief ch. 2 roses
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_64.jpg
# possible_answers:  A G per fess & paly cch<|>O S per pale<|>A B 2 chicots in saltire<|>G A arrowhead palewise from bull's attire inv = Odrowaz A<|>A G lion rampant
# result_id:  2  -- selected label:  O S per pale
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_65.jpg
# possible_answers:   swan; barry & lion; =; =   {GA, XG-AB}<|>G AO swan & border<|>O B rose<|>G AG per pale plain & barry<|>G A stirrup
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_66.jpg
# possible_answers:  G A arrowhead bendwise from bull's attire inv = Odrowaz B<|>O S 2 chicots in saltire<|>S X AG chief per pale<|>B O rose<|> cockatrice; per fess rompu sn; =; =   {BA; AG}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_68.jpg
# possible_answers:  O BG eagle ch. crescent<|>G AG fess of lozenges ch. fess overall<|>G A 2 swords in saltire<|>A G 3 fish naiant in pale<|>G A rose
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_70.jpg
# possible_answers:  A G arrowhead palewise from bull's attire inv = Odrowaz A<|>X G BA per fess & lion<|> rabbit salient; boar's head; =; =  {SA, SA}<|>S AA pale & chief<|>B A bend embattled-counterembattled
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_71.jpg
# possible_answers:  B O per pale<|>A GS falcon cr. rising from mount<|>A G per pale & bull's face cch<|>G A triquetra<|>S A canton
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_72.jpg
# possible_answers:  G A fess<|>B O 5 eagles
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_74.jpg
# possible_answers:   fess, 3 lions passt   {GA, OS}<|>- ILLEGIBLE<|>O BX AG eagle ch. crescent checky<|>A GO eagle cr. boned trefly<|>G OO bend betw 2 lions per bend
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_76.jpg
# possible_answers:  G AO bend betw 6 crowns<|>G AV doorway open acc. fess<|>X O AG bendy sn & pale<|> eagle demi; paly of 4  {SO, AG}<|>G A chief
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_77.jpg
# possible_answers:   per pale; serpent engorging child; anchor inv; barry & chevron  {AG, OSG, GA, XB-GA}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_78.jpg
# possible_answers:  O S lozengy
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_79.jpg
# possible_answers:  G O sun face
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_80.jpg
# possible_answers:  S A fess<|>G O chief<|>A G fess<|>S AO lion chained cr. & border<|>G BA chief ch. lion isst
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_81.jpg
# possible_answers:  G A fess disjointed dx<|>G A heron stat<|>O G crawfish<|>A G per pale & wheel cch<|>G A bendy embowed
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_82.jpg
# possible_answers:  G AB chief ch. panter isst<|>O S eagle's head<|>A G bendy of 8<|>A G per chevron grady isst sn<|>- ILLEGIBLE
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_83.jpg
# possible_answers:  G A 2 scytheblades addorsed<|>S GA chief ch. swan's head<|>A G per bend<|>A GG per bend sn & dragon's head<|>G A spade inv
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_84.jpg
# possible_answers:  G A spearhead in bend<|>O S triangled<|> dice; waterlily leaf; =; =   {GA, AV}<|>G AS tierced per chevron<|> yoke per bend; tierced per fess; =; =  {OS, GAS}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_85.jpg
# possible_answers:  S A per chevron grady<|>S A pily-barry<|>O SS bear isst on mount<|>G AA ram on mount<|>S A per bend & 2 talons cch
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_88.jpg
# possible_answers:  A G castle<|>A G paly of 4<|>A B pily-barry<|>A GO lion holding cup covered<|>A G per pale & fess cch
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_89.jpg
# possible_answers:  G O per pale<|>S A griffin segreant<|>A G wolf-hook curled<|>A GB fess betw 3 eagles<|>S AA pale acc. 6 roses
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_90.jpg
# possible_answers:  S A griffin segreant<|>S AS per pale plain & pily-barry<|>G A fess dancetty<|>S AG tierced per fess<|>A G per bend nebuly
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_91.jpg
# possible_answers:  B A horseshoe<|>A S ibex naissant<|>G AS doorway open<|>A VG branch sprouting 3 roses<|>O S 2 gambs in saltire
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_92.jpg
# possible_answers:  B AO per pale lion cr. & plain<|>G ABS per pale fess ch. mullet & plain<|>A N 2 boathook irons in saltire<|>A G per bend & bend cch & chief & terrace<|>A S 3 bars
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_93.jpg
# possible_answers:  G AA owl on mount<|>G A 2 demi-wheels addorsed<|>A S 2 bends<|>A S boar<|>O N wolf rampant
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_94.jpg
# possible_answers:  G AA barry ch. 6 crescents<|>S AG mount couped ch. chevron<|>G  A cat rampant<|>A G chicot per bend<|>A SG 2 reed maces in saltire & base
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_95.jpg
# possible_answers:  A B per chevron inv<|>A B per bend embattled<|>A S mill wheel<|>G X AS bend chevronny<|>- ILLEGIBLE
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_96.jpg
# possible_answers:  A S per bend<|>G A pale<|>G AV bend ch. 3 water lily leaves<|>X G SA per pale & chief<|>S X AG bend per pale
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_97.jpg
# possible_answers:  A S per bend undy & bend undy cch<|>A G 2 ibex horns addorsed<|>G A fess dancetty<|>A G 3 roses<|>G N savage's head
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_98.jpg
# possible_answers:  A G chief embattled<|>O S swan<|>B A 3 crescents (2 addorsed, 1 turned)<|>O S fess<|>G AS fess ch. barrulet
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_99.jpg
# possible_answers:  G A pale<|>A GG per chevron & chief<|>A S per pale & female head with hat<|>G S 3 bugle-horns in pale<|>B O panther
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_100.jpg
# possible_answers:  A GO lion roundely<|>X A BG per pale & per chevron embowed<|>O G per pale vallary<|>G X AB fess lozengy<|>- CREST only
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_101.jpg
# possible_answers:  S A per fess rompu sn<|>A GO tierced per fess<|>- CREST only<|>B O stag salient<|>B A stork
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_102.jpg
# possible_answers:  G AS tierced per chevron<|>O B fess<|>A G chevron<|>A X GS chief per pale<|>G AO 3 dices acc. mount
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_103.jpg
# possible_answers:  A G bend<|>G A dragon's head<|>B O axe per bend<|>S X OA chief per pale<|>G A fess embattled
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_104.jpg
# possible_answers:  A G axe in bend<|>G A axe in bend<|>G A chief<|>A SO bend ch. 3 roundels<|>B O 3 crescents (2 addorsed, 1 turned)
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_105.jpg
# possible_answers:  G AB tierced per bend<|>A G chief embattled<|>O SV boar on mount<|> swan; lozengy; =; =   {GA, AB}<|>A S fess
# result_id:  1  -- selected label:  G AB tierced per bend
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_106.jpg
# possible_answers:  A GG falcon rising from saltire in base<|>A G 2 chevrons crenellated<|>O G per fess enclaved downwards<|>A GG per pale fess & plain<|>O G 2 lions passt guard
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_107.jpg
# possible_answers:  A V per pale<|>X O AS per pale & fess<|>- CREST only<|>- CREST only<|>X G AB lozengy & chief
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_108.jpg
# possible_answers:  G A fish winged in bend<|>A S rose<|>G AG fess ch. 3 roundels<|>A SG griffin on mount<|>X A GS per fess & estoile
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_109.jpg
# possible_answers:  A G barry embattled<|>A G lion's head<|>G AA spur erect on mount<|>A S elm branch with 3 leaves downwards
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_110.jpg
# possible_answers:  S O 3 estoiles<|>O S bend<|>S A wooden table<|>O B pitchfork iron (points in saltire)<|>G A 3 sickles  (2 addorsed, 1st per fess)
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_111.jpg
# possible_answers:  S O barry of 4<|>S OS chief ch. talbot
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_112.jpg
# possible_answers:  O SA eagle ch. crescent
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_113.jpg
# possible_answers:  O G fool's head with belled bonnet<|>S A unicorn salient<|>A GB lion acc. fess<|>G X AB fess bendy<|>A G lion rampant
# result_id:  4  -- selected label:  G X AB fess bendy
# result_id:  1  -- selected label:  O G fool's head with belled bonnet
# result_id:  3  -- selected label:  A GB lion acc. fess
# result_id:  2  -- selected label:  S A unicorn salient
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_114.jpg
# possible_answers:  G A ram's face<|> per pale; lion; =; =   {AS, GA}<|>A G paly of 4<|>- CREST only
# result_id:  1  -- selected label:  G A ram's face
# result_id:  2  -- selected label:   per pale; lion; =; =   {AS, GA}
# result_id:  4  -- selected label:  - CREST only
# result_id:  3  -- selected label:  A G paly of 4
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_115.jpg
# possible_answers:  G OO bend & border<|>A G per pale & fess cch<|>A G lion rampant<|>- CREST only
# result_id:  1  -- selected label:  G OO bend & border
# result_id:  2  -- selected label:  A G per pale & fess cch
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_116.jpg
# possible_answers:  A S cock<|>X G AB lozengy & fess<|>B AB bend ch. 3 roses<|>S X AG chief per pale<|>B X AG negress's bust affronté vested checky & border checky
# result_id:  5  -- selected label:  B X AG negress's bust affronté vested checky & border checky
# result_id:  2  -- selected label:  X G AB lozengy & fess
# result_id:  3  -- selected label:  B AB bend ch. 3 roses
# result_id:  4  -- selected label:  S X AG chief per pale
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_117.jpg
# possible_answers:  O G pale<|>G A 2 maces in saltire<|>O N marten<|>O AS chief barry dancetty<|>G A falcon rising
# result_id:  4  -- selected label:  O AS chief barry dancetty
# result_id:  5  -- selected label:  G A falcon rising
# result_id:  2  -- selected label:  G A 2 maces in saltire
# result_id:  1  -- selected label:  O G pale
# result_id:  3  -- selected label:  O N marten
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_118.jpg
# possible_answers:  G A arrowhead on hoof in bend<|>G A mitten<|>G A castle<|>A GAG per pale barry & dragon<|>- CREST only
# result_id:  4  -- selected label:  A GAG per pale barry & dragon
# result_id:  5  -- selected label:  - CREST only
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_119.jpg
# possible_answers:  G OAS 3 gemstones & chief ch. eagle isst = Sulima A<|>G S 3 bugle-horns stringed in pairle<|>G A rose<|>G A bend couped 'S'-shaped = Druzyna<|>G A 3 lozenges in bend
# result_id:  1  -- selected label:  G OAS 3 gemstones & chief ch. eagle isst = Sulima A
# result_id:  4  -- selected label:  G A bend couped 'S'-shaped = Druzyna
# result_id:  2  -- selected label:  G S 3 bugle-horns stringed in pairle
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_120.jpg
# possible_answers:  B X AG 3 bends checky<|>A GO chief indented ch. lion passt guard<|>A G gironny engrailed<|>O G per pale & fess cch<|>S O cross moline
# result_id:  5  -- selected label:  S O cross moline
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_121.jpg
# possible_answers:  O G wolf-hook in bend<|>A G 3 wolf-hooks<|>A VV fess and filet enhanced<|>G O stirrup<|>G A 3 eagles
# result_id:  3  -- selected label:  A VV fess and filet enhanced
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_122.jpg
# possible_answers:  O G antler per pale<|> helmet with swan crest; fess isst three-stemmed flower; =; =  {BAA, OBGV}<|>S A 5 roundels in saltire<|>G O stirrup<|>A S bird
# result_id:  5  -- selected label:  A S bird
# result_id:  2  -- selected label:   helmet with swan crest; fess isst three-stemmed flower; =; =  {BAA, OBGV}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_123.jpg
# possible_answers:  Z G chief<|>A BG barry & label<|>B OA bend sn & canton<|>- ILLEGIBLE<|>S AA chevron, billety
# result_id:  4  -- selected label:  - ILLEGIBLE
# result_id:  2  -- selected label:  A BG barry & label
# result_id:  1  -- selected label:  Z G chief
# result_id:  3  -- selected label:  B OA bend sn & canton
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_124.jpg
# possible_answers:  S O bend<|>B AO 6 fleurs-de-lis & chief indented<|>A G 2 staves flory in saltire<|>G A 3 annulets<|>- ILLEGIBLE
# result_id:  3  -- selected label:  A G 2 staves flory in saltire
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_125.jpg
# possible_answers:  O S harp<|>V A barruly<|>G A bend<|>A G trammel in bend<|>A BS 3 increscents acc. estoile in fess point
# result_id:  4  -- selected label:  A G trammel in bend
# result_id:  5  -- selected label:  A BS 3 increscents acc. estoile in fess point
# result_id:  1  -- selected label:  O S harp
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_126.jpg
# possible_answers:  S OO viol per bend, billety<|>B A glove in bend<|>A GO wing boned trefly
# result_id:  1  -- selected label:  S OO viol per bend, billety
# result_id:  2  -- selected label:  B A glove in bend
# result_id:  3  -- selected label:  A GO wing boned trefly
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_127.jpg
# possible_answers:  B O talon<|>G AS talbot's head collared<|>O V tree
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_128.jpg
# possible_answers:  S O wing fesswise<|>O SS fess betw 3 roundels
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_129.jpg
# possible_answers:  S O crown<|>- CREST only<|>A G 3 increscents (2:1)
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_132.jpg
# possible_answers:   bull's face cr.; per fess; griffin passt    {OS, GA, BO}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_133.jpg
# possible_answers:  G AO eagle ch. crescent<|>X AS GB per bend & bend checky<|>A G mill-rind<|>A S 2 lozenges
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_134.jpg
# possible_answers:  A G griffin segreant
# result_id:  1  -- selected label:  A G griffin segreant
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_135.jpg
# possible_answers:  O SAG per pale lion  isst & eagle isst<|>A G dragon with eagle's wings<|>B O eagle<|>G A eagle
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_136.jpg
# possible_answers:   checky & chief ch. griffin barruly isst; griffin  {ABGX-VA; AG}<|> griffin; griffin   {AG, AG}<|>B O eagle cr.<|> 2 lions passt guard; nettle leaf; =; =  {OB, GA}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_137.jpg
# possible_answers:   nettle leaf; 2 lions passt guard, semy of hearts; =; =  {GA, OBG}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_138.jpg
# possible_answers:   per fess & 2 swords in saltire; barry acc. crancelin per bend; lion, semy of hearts; 3 waterlily leaves inv :E: eagle    {XG-SA, OSV, OSG, AG; BO}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_139.jpg
# possible_answers:   per pale; eagle; =; =  {AG, OB}<|>X GS AO per pale & eagle per pale<|>X SG OA per pale & eagle per pale<|>- ILLEGIBLE<|>A G checky
# result_id:  2  -- selected label:  X GS AO per pale & eagle per pale
# result_id:  1  -- selected label:   per pale; eagle; =; =  {AG, OB}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_140.jpg
# possible_answers:  A GA chief ch. arm vested<|>G A ibex naissant<|>S O wheel<|>O B 3 escutcheons<|>A G chief
# result_id:  2  -- selected label:  G A ibex naissant
# result_id:  1  -- selected label:  A GA chief ch. arm vested
# result_id:  5  -- selected label:  A G chief
# result_id:  3  -- selected label:  S O wheel
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_141.jpg
# possible_answers:  S O griffin segreant<|>A G 2 talons in saltire
# result_id:  2  -- selected label:  A G 2 talons in saltire
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_142.jpg
# possible_answers:  A G 2 talons in saltire<|>G VA per pale plain & fess<|>O S moorcock<|>S O 3 wolf-hooks in pale<|>- CREST only
# result_id:  1  -- selected label:  A G 2 talons in saltire
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_143.jpg
# possible_answers:  S A yoke per bend
# result_id:  1  -- selected label:  S A yoke per bend
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_146.jpg
# possible_answers:  B O 2 axes addorsed<|>A GV lion holding trunk<|>G A pale<|>G A 2 wings<|>B OX AS stag's face
# result_id:  1  -- selected label:  B O 2 axes addorsed
# result_id:  2  -- selected label:  A GV lion holding trunk
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_147.jpg
# possible_answers:  O B lion's head engorging annulet<|>B A 2 wings<|>O S 3 antlers in pale<|>A B stag's head<|>S AG chief ch. bend
# result_id:  5  -- selected label:  S AG chief ch. bend
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_148.jpg
# possible_answers:  O S 3 antlers in pale<|>S O saw per bend<|>A N fox rampant cr.<|>A S donkey salient
# result_id:  4  -- selected label:  A S donkey salient
# result_id:  1  -- selected label:  O S 3 antlers in pale
# result_id:  2  -- selected label:  S O saw per bend
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_149.jpg
# possible_answers:  - ILLEGIBLE<|>B A 2 sickles addorsed<|>G A ibex segreant<|>A BG per chevron grady isst base dx tipped with star
# result_id:  1  -- selected label:  - ILLEGIBLE
# result_id:  3  -- selected label:  G A ibex segreant
# result_id:  2  -- selected label:  B A 2 sickles addorsed
# result_id:  4  -- selected label:  A BG per chevron grady isst base dx tipped with star
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_150.jpg
# possible_answers:  G AO cat chained cr.<|>G A rake<|>G A 2 bars dancetty<|>G A pily-barry<|>- ILLEGIBLE
# result_id:  1  -- selected label:  G AO cat chained cr.
# result_id:  3  -- selected label:  G A 2 bars dancetty
# result_id:  2  -- selected label:  G A rake
# result_id:  4  -- selected label:  G A pily-barry
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_151.jpg
# possible_answers:  - ILLEGIBLE<|>G A attire<|>O G qtly<|>A GV lion and eagle's claw winged sn<|> unicorn; bendy  {GA, OS}
# result_id:  5  -- selected label:   unicorn; bendy  {GA, OS}
# result_id:  3  -- selected label:  O G qtly
# result_id:  2  -- selected label:  G A attire
# result_id:  4  -- selected label:  A GV lion and eagle's claw winged sn
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_152.jpg
# possible_answers:  O NA fox rampant carrying goose<|>G S ram's face<|>A S donkey's head<|>G A talbot rampant<|>B A 2 crescents addorsed
# result_id:  5  -- selected label:  B A 2 crescents addorsed
# result_id:  4  -- selected label:  G A talbot rampant
# result_id:  2  -- selected label:  G S ram's face
# result_id:  1  -- selected label:  O NA fox rampant carrying goose
# result_id:  3  -- selected label:  A S donkey's head
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_153.jpg
# possible_answers:  G X  AG per pale plain & 2 bars
# result_id:  1  -- selected label:  G X  AG per pale plain & 2 bars
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_156.jpg
# possible_answers:  A GO eagle ch. crescent
# result_id:  1  -- selected label:  A GO eagle ch. crescent
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_157.jpg
# possible_answers:   eagle ch. crescent; lion passt cr. & border compony; =; qtly  {AGO, AS-AG, AS}
# result_id:  1  -- selected label:   eagle ch. crescent; lion passt cr. & border compony; =; qtly  {AGO, AS-AG, AS}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_160.jpg
# possible_answers:  B AG fess  ch.rose<|>V A fess<|>A G elm branch (formed as a knot)<|>A B paly<|>A S bear naissant
# result_id:  5  -- selected label:  A S bear naissant
# result_id:  3  -- selected label:  A G elm branch (formed as a knot)
# result_id:  1  -- selected label:  B AG fess  ch.rose
# result_id:  4  -- selected label:  A B paly
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_161.jpg
# possible_answers:  A G tower<|>O BA bend ch. mullet<|>O S moor holding flower<|>O X SG 2 wings<|>A S bend
# result_id:  4  -- selected label:  O X SG 2 wings
# result_id:  1  -- selected label:  A G tower
# result_id:  2  -- selected label:  O BA bend ch. mullet
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_162.jpg
# possible_answers:  O G fox rampant<|>A GG bend undy acc. mullet in chf sn<|>B A per chevron<|>- CREST only
# result_id:  2  -- selected label:  A GG bend undy acc. mullet in chf sn
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_164.jpg
# possible_answers:  S A 3 trees<|>G O 3 mallets<|>G A buckle<|>A G stag salient<|>A G chevronny of 4
# result_id:  1  -- selected label:  S A 3 trees
# result_id:  5  -- selected label:  A G chevronny of 4
# result_id:  4  -- selected label:  A G stag salient
# result_id:  3  -- selected label:  G A buckle
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_165.jpg
# possible_answers:  X S AG per bend checky & plain<|>O B pale<|>G A pile isst betw 2 peaks<|>B A duck<|>- CREST only
# result_id:  1  -- selected label:  X S AG per bend checky & plain
# result_id:  3  -- selected label:  G A pile isst betw 2 peaks
# result_id:  4  -- selected label:  B A duck
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_168.jpg
# possible_answers:  A G per fess & paly cch<|>G O 2 bends<|>A G per pale & per chevron cch<|>O X AG 2 bars checky<|>G A per chevron
# result_id:  4  -- selected label:  O X AG 2 bars checky
# result_id:  5  -- selected label:  G A per chevron
# result_id:  3  -- selected label:  A G per pale & per chevron cch
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_169.jpg
# possible_answers:  A S ibex horn<|>O G per bend<|>G A yoke per bend<|>G A 2 bars<|>G A tower
# result_id:  2  -- selected label:  O G per bend
# result_id:  3  -- selected label:  G A yoke per bend
# result_id:  1  -- selected label:  A S ibex horn
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_170.jpg
# possible_answers:  B A wolf-hook inv<|>X BO AG per pale lozengy & lion<|>A G pily-bendy<|>O A 2 antlers per fess<|>A GS tierced per fess
# result_id:  1  -- selected label:  B A wolf-hook inv
# result_id:  2  -- selected label:  X BO AG per pale lozengy & lion
# result_id:  5  -- selected label:  A GS tierced per fess
# result_id:  3  -- selected label:  A G pily-bendy
# result_id:  4  -- selected label:  O A 2 antlers per fess
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_171.jpg
# possible_answers:  A S ibex horn<|>A G- chief embattled & border<|>A S per pale & annulet cch<|>G A 3 arrows per saltire and pale<|>A S sawbuck
# result_id:  5  -- selected label:  A S sawbuck
# result_id:  3  -- selected label:  A S per pale & annulet cch
# result_id:  2  -- selected label:  A G- chief embattled & border
# result_id:  1  -- selected label:  A S ibex horn
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_172.jpg
# possible_answers:  G A fish embowed<|>A G qtly per fess and per pale indented<|>O G lion guard<|>G O camel<|>A G per saltire
# result_id:  3  -- selected label:  O G lion guard
# result_id:  1  -- selected label:  G A fish embowed
# result_id:  5  -- selected label:  A G per saltire
# result_id:  2  -- selected label:  A G qtly per fess and per pale indented
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_173.jpg
# possible_answers:  A B barry of 4<|>B A unicorn salient<|>G A pily-barry<|>S A fess<|>A G 2 scissors
# result_id:  2  -- selected label:  B A unicorn salient
# result_id:  4  -- selected label:  S A fess
# result_id:  1  -- selected label:  A B barry of 4
# result_id:  5  -- selected label:  A G 2 scissors
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_174.jpg
# possible_answers:  B A tower<|>B A unicorn salient<|>G S ram reguard<|>A BA bend undy ch. 3 fish<|>G A goose
# result_id:  1  -- selected label:  B A tower
# result_id:  2  -- selected label:  B A unicorn salient
# result_id:  3  -- selected label:  G S ram reguard
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_175.jpg
# possible_answers:  G A 3 axes<|>A GO horsebray with cord<|>G A horsebray<|>A G 3 axes<|>G X SA harpoon head erect party per fess
# result_id:  5  -- selected label:  G X SA harpoon head erect party per fess
# result_id:  2  -- selected label:  A GO horsebray with cord
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_176.jpg
# possible_answers:  S A fess<|>O B 3 lozenges in bend<|>A G 3 escallops<|>G O fess<|>S A fess embattled
# result_id:  4  -- selected label:  G O fess
# result_id:  2  -- selected label:  O B 3 lozenges in bend
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_177.jpg
# possible_answers:  A SG lion acc. fess<|>B O increscent<|>A B sickle<|>O S boar's head<|>A B panther
# result_id:  1  -- selected label:  A SG lion acc. fess
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_178.jpg
# possible_answers:  A GO tierced per fess<|>G Z bend<|>A G per pale & wheel cch<|>A G fleur-de-lis<|>A S bear's head chained
# result_id:  4  -- selected label:  A G fleur-de-lis
# result_id:  3  -- selected label:  A G per pale & wheel cch
# result_id:  2  -- selected label:  G Z bend
# result_id:  1  -- selected label:  A GO tierced per fess
# result_id:  5  -- selected label:  A S bear's head chained
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_179.jpg
# possible_answers:   3 chevrons crenelated; shovel per bend; =; =   {AG, BO}<|>A GG falcon rising from saltire in base<|>G A fess dancetty<|>A G bendy of 4<|>A G per fess & pale cch
# result_id:  1  -- selected label:   3 chevrons crenelated; shovel per bend; =; =   {AG, BO}
# result_id:  3  -- selected label:  G A fess dancetty
# result_id:  2  -- selected label:  A GG falcon rising from saltire in base
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_182.jpg
# possible_answers:   lion; lion q.f.; =; = :E: chevronny  {OS, AG, AG}
# result_id:  1  -- selected label:   lion; lion q.f.; =; = :E: chevronny  {OS, AG, AG}
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_183.jpg
# possible_answers:  B A greyhound courant
# result_id:  1  -- selected label:  B A greyhound courant
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_184.jpg
# possible_answers:  A S 3 lozenges in bend<|>S A eagle<|>S A qtly<|>S O barry<|>G A bend sn
# result_id:  5  -- selected label:  G A bend sn
# result_id:  2  -- selected label:  S A eagle
# result_id:  3  -- selected label:  S A qtly
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_185.jpg
# possible_answers:  O GBA 4 pales & canton ch. mullet<|>O G 4 pales<|>G AO 3 waterlily leaves inv & chief<|>B OGO cross ch. 5 escallops, crusily<|>G A eagle
# result_id:  3  -- selected label:  G AO 3 waterlily leaves inv & chief
# result_id:  2  -- selected label:  O G 4 pales
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_186.jpg
# possible_answers:  A G 3 waterlily leaves inv<|> 3 grapes; fess dancetty acc. eagle in chf dx; =; =   {AS, OGS}<|>B OG bend ch. 3 chevrons<|>A S chevron<|>- CREST only
# result_id:  1  -- selected label:  A G 3 waterlily leaves inv
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_187.jpg
# possible_answers:  S AA 6 fleurs-de-lis & chief<|>G O cross patonce<|>A G per bend<|>- ILLEGIBLE<|>S O 3 escallops
# result_id:  1  -- selected label:  S AA 6 fleurs-de-lis & chief
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_188.jpg
# possible_answers:  A SG fess acc. lion q.f. isst<|>O GV saltire betw 4 water-lily leaves inv<|>G A fess embattled-counterembattled<|>- CREST only<|>- CREST only
# result_id:  2  -- selected label:  O GV saltire betw 4 water-lily leaves inv
# result_id:  3  -- selected label:  G A fess embattled-counterembattled
# result_id:  1  -- selected label:  A SG fess acc. lion q.f. isst
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_189.jpg
# possible_answers:  S AA lion cr., trefly<|>O B 3 mallets<|>A S 3 crampons per pale<|>S X AO lion hooded<|>O GBA 4 pales & canton ch. mullet
# result_id:  4  -- selected label:  S X AO lion hooded
# result_id:  5  -- selected label:  O GBA 4 pales & canton ch. mullet
# result_id:  2  -- selected label:  O B 3 mallets
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_190.jpg
# possible_answers:  A G gironny<|> bend betw 6 billets; crown imperial; =; =  {AGG, GA}<|>G AO 3 waterlily leaves inv & chief<|>V OE semy of crosslets & chief<|>A GV fess betw 3 waterlily leaves
# result_id:  3  -- selected label:  G AO 3 waterlily leaves inv & chief
# result_id:  2  -- selected label:   bend betw 6 billets; crown imperial; =; =  {AGG, GA}
# result_id:  4  -- selected label:  V OE semy of crosslets & chief
# result_id:  1  -- selected label:  A G gironny
# result_id:  5  -- selected label:  A GV fess betw 3 waterlily leaves
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_191.jpg
# possible_answers:  O G barruly<|>A G lion q.f. cr.<|> eagle; lion q.f. cr.; =; barruly    {OS, AG, OG}<|>O X AG fess vairy<|>A G 3 lozenges (2:1)
# result_id:  3  -- selected label:   eagle; lion q.f. cr.; =; barruly    {OS, AG, OG}
# result_id:  1  -- selected label:  O G barruly
# result_id:  4  -- selected label:  O X AG fess vairy
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_192.jpg
# possible_answers:  O G fess dancetty<|>G A fess dancetty<|>G A 3 gables (2 reversed : 1)<|> pp[barruly; 2 barbels addorsed, crusily]; lion q.f.; =; = :E: lion  {OG, GO, GA, OS}<|> pp[barruly; 2 barbels addorsed, crusily]; lion q.f.; =; = :E: checky of 9  {OG, GO, GA, AG}
# result_id:  3  -- selected label:  G A 3 gables (2 reversed : 1)
# result_id:  4  -- selected label:   pp[barruly; 2 barbels addorsed, crusily]; lion q.f.; =; = :E: lion  {OG, GO, GA, OS}
# result_id:  5  -- selected label:   pp[barruly; 2 barbels addorsed, crusily]; lion q.f.; =; = :E: checky of 9  {OG, GO, GA, AG}
# result_id:  1  -- selected label:  O G fess dancetty
# result_id:  2  -- selected label:  G A fess dancetty
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_193.jpg
# possible_answers:  A G rose<|>A S 2 gambs in saltire<|>A S 2 bars of lozenges<|>S O roundelly<|>A G roundelly
# result_id:  3  -- selected label:  A S 2 bars of lozenges
# result_id:  2  -- selected label:  A S 2 gambs in saltire
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_194.jpg
# possible_answers:   ps[eagle, paly of 4   {AG, OG}]<|> ps[eagle, paly of 4   {AG, OG}]<|>B AG basket of fruit<|>B OA fess embattled-counterembattled betw 3 martlets<|>- CREST only
# result_id:  4  -- selected label:  B OA fess embattled-counterembattled betw 3 martlets
# result_id:  3  -- selected label:  B AG basket of fruit
# result_id:  5  -- selected label:  - CREST only
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_195.jpg
# possible_answers:   mill-rind; 3 roses; =; =  {OS, AG}<|>A GO chief indented ch. lion passt guard<|>B A cross<|>A B 3 bends
# result_id:  3  -- selected label:  B A cross
# result_id:  1  -- selected label:   mill-rind; 3 roses; =; =  {OS, AG}
# result_id:  2  -- selected label:  A GO chief indented ch. lion passt guard
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_196.jpg
# possible_answers:  A BA canton ch. mill-rind<|>A VG 3 pales & chief
# result_id:  1  -- selected label:  A BA canton ch. mill-rind
# result_id:  2  -- selected label:  A VG 3 pales & chief
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_197.jpg
# possible_answers:  G OO cross, billety<|>- ILLEGIBLE<|>A G cross moline
# result_id:  1  -- selected label:  G OO cross, billety
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_200.jpg
# possible_answers:  A S fretty<|>A SG pily-paly of 3 acc. 3 martlets in chf<|>S A per fess & 2 arms in pale cch<|>G AO rose & border<|>G AO bend acc. escarbuncle
# result_id:  3  -- selected label:  S A per fess & 2 arms in pale cch
# result_id:  4  -- selected label:  G AO rose & border
# result_id:  1  -- selected label:  A S fretty
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_201.jpg
# possible_answers:  G ABA bend ch. rose & border<|>G AS chief ch. mullet<|>G AO rose & border<|>O GA chief ch. mullet<|>O GA chief ch. mullet
# result_id:  1  -- selected label:  G ABA bend ch. rose & border
# result_id:  3  -- selected label:  G AO rose & border
# result_id:  2  -- selected label:  G AS chief ch. mullet
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_202.jpg
# possible_answers:  X G BA per fess & lion<|>B AO swan & border<|>G AB fess & border<|>O SA wing fesswise ch. wingbone trefly<|>O G per saltire
# result_id:  4  -- selected label:  O SA wing fesswise ch. wingbone trefly
# result_id:  2  -- selected label:  B AO swan & border
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_203.jpg
# possible_answers:  A S 3 cocks<|>S OO spearhead in bend & border<|>S O fleur-de-lis<|>G A ibex segreant<|>A G 3 ibex horns
# result_id:  4  -- selected label:  G A ibex segreant
# result_id:  3  -- selected label:  S O fleur-de-lis
# result_id:  2  -- selected label:  S OO spearhead in bend & border
# result_id:  5  -- selected label:  A G 3 ibex horns
# -----
# image: images/Donaueschinger Wappenbuch - Cod Donaueschingen 496_204.jpg
# ...
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_86.jpg
# possible_answers:  A BG barry & border<|>G OO lion, billety<|>O B 5 towers<|>O G 3 crescents (2:1)<|>A SO cross fretty
# result_id:  5  -- selected label:  A SO cross fretty
# result_id:  4  -- selected label:  O G 3 crescents (2:1)
# result_id:  3  -- selected label:  O B 5 towers
# result_id:  2  -- selected label:  G OO lion, billety
# result_id:  1  -- selected label:  A BG barry & border
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_87.jpg
# possible_answers:  X GA BO per fess & cross moline ch. 5 escallops<|>A G 3 roundels<|>V E barry<|>X G AB checky & chief<|>B O cross
# result_id:  3  -- selected label:  V E barry
# result_id:  4  -- selected label:  X G AB checky & chief
# result_id:  5  -- selected label:  B O cross
# result_id:  1  -- selected label:  X GA BO per fess & cross moline ch. 5 escallops
# result_id:  2  -- selected label:  A G 3 roundels
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_88.jpg
# possible_answers:  O B per pale<|>G ASA fess ch. lion passt acc. fess dancetty in chf<|>G A lion rampant<|>A G 3 eagles<|>A S 3 escutcheons
# result_id:  1  -- selected label:  O B per pale
# result_id:  4  -- selected label:  A G 3 eagles
# result_id:  5  -- selected label:  A S 3 escutcheons
# result_id:  2  -- selected label:  G ASA fess ch. lion passt acc. fess dancetty in chf
# result_id:  3  -- selected label:  G A lion rampant
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_89.jpg
# possible_answers:  A G canton<|>G A 3 chevrons<|>O S eagle doubleheaded<|>A B 3 bottles<|>A B 3 chevrons
# result_id:  2  -- selected label:  G A 3 chevrons
# result_id:  3  -- selected label:  O S eagle doubleheaded
# result_id:  4  -- selected label:  A B 3 bottles
# result_id:  5  -- selected label:  A B 3 chevrons
# result_id:  1  -- selected label:  A G canton
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_90.jpg
# possible_answers:  A S chevron<|>A S 6 lozenges<|>G OO 3 cinquefoils & chief<|>O G 3 roundels<|>A G+ cross engrailed acc. escutch {Sa lion Ar} in chf dx
# result_id:  3  -- selected label:  G OO 3 cinquefoils & chief
# result_id:  4  -- selected label:  O G 3 roundels
# result_id:  5  -- selected label:  A G+ cross engrailed acc. escutch {Sa lion Ar} in chf dx
# result_id:  2  -- selected label:  A S 6 lozenges
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_91.jpg
# possible_answers:  A G checky<|>A G fess<|>B A bend<|>B GO lion & chief<|>G A 3 bars gemel
# result_id:  1  -- selected label:  A G checky
# result_id:  2  -- selected label:  A G fess
# result_id:  3  -- selected label:  B A bend
# result_id:  5  -- selected label:  G A 3 bars gemel
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_92.jpg
# possible_answers:  O G lion rampant<|> 3 fleurs-de-lis p.n.; lion, billety; =; =   {AG, ASS}<|>X G AB barry & bend<|>V Z 3 pales<|>G O bend
# result_id:  5  -- selected label:  G O bend
# result_id:  4  -- selected label:  V Z 3 pales
# result_id:  1  -- selected label:  O G lion rampant
# result_id:  2  -- selected label:   3 fleurs-de-lis p.n.; lion, billety; =; =   {AG, ASS}
# result_id:  3  -- selected label:  X G AB barry & bend
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_93.jpg
# possible_answers:  O BG barry acc. 3 annulets in chf<|>A G crescent<|>A GV escutcheon acc. orle of martlets<|>G O bend
# result_id:  2  -- selected label:  A G crescent
# result_id:  4  -- selected label:  G O bend
# result_id:  3  -- selected label:  A GV escutcheon acc. orle of martlets
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_95.jpg
# possible_answers:  B OG semy of fleurs-de-lis & bend
# result_id:  1  -- selected label:  B OG semy of fleurs-de-lis & bend
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_98.jpg
# possible_answers:   pq[lion, lion guard; = ; = :: label]; semy of fleurs-de-lis & bend ch. 3 lions; = ; =   {AG, GO, B; BGRG}
# result_id:  1  -- selected label:   pq[lion, lion guard; = ; = :: label]; semy of fleurs-de-lis & bend ch. 3 lions; = ; =   {AG, GO, B; BGRG}
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_103.jpg
# possible_answers:  B AO tower, semy of fleurs-de-lis<|>G A semy of fleurs-de-lis<|>A G vairy<|>O GB castle acc. 2 axes in chf<|>O Z lion cr.
# result_id:  4  -- selected label:  O GB castle acc. 2 axes in chf
# result_id:  5  -- selected label:  O Z lion cr.
# result_id:  2  -- selected label:  G A semy of fleurs-de-lis
# result_id:  1  -- selected label:  B AO tower, semy of fleurs-de-lis
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_104.jpg
# possible_answers:   lion & border flory; 3 pales & chief ch. 3 dragons wingless; = ;=  {BAGO, OBGO}<|>A G lion rampant<|> 3 fleurs-de-lis; lion   {BO, GO}<|>G A tower<|>O S 3 estoiles
# result_id:  4  -- selected label:  G A tower
# result_id:  5  -- selected label:  O S 3 estoiles
# result_id:  3  -- selected label:   3 fleurs-de-lis; lion   {BO, GO}
# result_id:  2  -- selected label:  A G lion rampant
# result_id:  1  -- selected label:   lion & border flory; 3 pales & chief ch. 3 dragons wingless; = ;=  {BAGO, OBGO}
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_105.jpg
# possible_answers:  O B dolphin<|>O SS lion, crusily<|>B A tower & bend, flory<|>O G lion rampant<|>O G checky
# result_id:  4  -- selected label:  O G lion rampant
# result_id:  2  -- selected label:  O SS lion, crusily
# result_id:  1  -- selected label:  O B dolphin
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_106.jpg
# possible_answers:  O P 3 leopards' heads cr.<|>G A fess<|>B A 3 towers<|>B AO 3 towers, flory<|>B O barry
# result_id:  2  -- selected label:  G A fess
# result_id:  3  -- selected label:  B A 3 towers
# result_id:  5  -- selected label:  B O barry
# result_id:  4  -- selected label:  B AO 3 towers, flory
# result_id:  1  -- selected label:  O P 3 leopards' heads cr.
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_107.jpg
# possible_answers:  S O cross engrailed<|> bend ch. 3 escallops; 3 flanchis & chief; =; =   {GBO , BOO}<|>A G lion rampant<|>G A qtly<|>O SS bend betw 6 martlets
# result_id:  4  -- selected label:  G A qtly
# result_id:  3  -- selected label:  A G lion rampant
# result_id:  1  -- selected label:  S O cross engrailed
# result_id:  2  -- selected label:   bend ch. 3 escallops; 3 flanchis & chief; =; =   {GBO , BOO}
# result_id:  5  -- selected label:  O SS bend betw 6 martlets
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_108.jpg
# possible_answers:  A S lion rampant<|>G X AB chief checky<|>A B fess of lozenges
# result_id:  2  -- selected label:  G X AB chief checky
# result_id:  3  -- selected label:  A B fess of lozenges
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_111.jpg
# possible_answers:  B O wolf passt<|>O V cross moline<|>O V cross<|>A GO cross ch. 8 roundels<|>O GG lion, crusily
# result_id:  3  -- selected label:  O V cross
# result_id:  5  -- selected label:  O GG lion, crusily
# result_id:  4  -- selected label:  A GO cross ch. 8 roundels
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_112.jpg
# possible_answers:  A S 3 bars<|>O B lion rampant<|>G A 3 eagles<|>A S barry of 4<|>B A 2 barbels addorsed
# result_id:  1  -- selected label:  A S 3 bars
# result_id:  2  -- selected label:  O B lion rampant
# result_id:  3  -- selected label:  G A 3 eagles
# result_id:  5  -- selected label:  B A 2 barbels addorsed
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_113.jpg
# possible_answers:  X O OG qtly acc. 2 lions (Q2+3)<|>G AB chevron acc. mullet in chf dx<|>O S chief<|>A G cross moline<|>B O 3 lions
# result_id:  1  -- selected label:  X O OG qtly acc. 2 lions (Q2+3)
# result_id:  2  -- selected label:  G AB chevron acc. mullet in chf dx
# result_id:  3  -- selected label:  O S chief
# result_id:  4  -- selected label:  A G cross moline
# result_id:  5  -- selected label:  B O 3 lions
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_114.jpg
# possible_answers:  A O chief indented<|>A G checky<|>A G bendy<|>A GS fess acc. lion isst<|>A G cross
# result_id:  1  -- selected label:  A O chief indented
# result_id:  3  -- selected label:  A G bendy
# result_id:  2  -- selected label:  A G checky
# result_id:  5  -- selected label:  A G cross
# result_id:  4  -- selected label:  A GS fess acc. lion isst
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_115.jpg
# possible_answers:  O G fess dancetty<|>A V tree<|>G O fess
# result_id:  1  -- selected label:  O G fess dancetty
# result_id:  2  -- selected label:  A V tree
# result_id:  3  -- selected label:  G O fess
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_124.jpg
# possible_answers:  G O 2 lions passt guard
# result_id:  1  -- selected label:  G O 2 lions passt guard
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_125.jpg
# possible_answers:  O BG bendy & border
# result_id:  1  -- selected label:  O BG bendy & border
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_135.jpg
# possible_answers:  G O eagle<|>X S AG barruly & lion collared<|>G O 3 buckles<|>O G 3 chevrons<|>G OO 2 bars acc. orle of martlets
# result_id:  1  -- selected label:  G O eagle
# result_id:  4  -- selected label:  O G 3 chevrons
# result_id:  2  -- selected label:  X S AG barruly & lion collared
# result_id:  3  -- selected label:  G O 3 buckles
# result_id:  5  -- selected label:  G OO 2 bars acc. orle of martlets
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_136.jpg
# possible_answers:  O BG paly & chief<|>O G lion rampant<|>X G BO barruly & lion<|>O G 3 hands<|>O S 6 boars
# result_id:  2  -- selected label:  O G lion rampant
# result_id:  1  -- selected label:  O BG paly & chief
# result_id:  3  -- selected label:  X G BO barruly & lion
# result_id:  4  -- selected label:  O G 3 hands
# result_id:  5  -- selected label:  O S 6 boars
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_137.jpg
# possible_answers:  G O 2 bars<|>G OS 3 buckles & label<|>B AO cross, crusily<|>B OO cross, crusily<|>O G 3 chevrons
# result_id:  1  -- selected label:  G O 2 bars
# result_id:  2  -- selected label:  G OS 3 buckles & label
# result_id:  5  -- selected label:  O G 3 chevrons
# result_id:  4  -- selected label:  B OO cross, crusily
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_138.jpg
# possible_answers:  G O 3 chevrons<|>S A chevron<|>A G 7 bars<|>O G fleur-de-lis<|>A G cinquefoil
# result_id:  4  -- selected label:  O G fleur-de-lis
# result_id:  3  -- selected label:  A G 7 bars
# result_id:  5  -- selected label:  A G cinquefoil
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_139.jpg
# possible_answers:  G O 3 lions<|>G AA cross, crusily<|>O G lion rampant<|>B O 3 buckles<|>G A 3 mallets
# result_id:  3  -- selected label:  O G lion rampant
# result_id:  1  -- selected label:  G O 3 lions
# result_id:  2  -- selected label:  G AA cross, crusily
# result_id:  4  -- selected label:  B O 3 buckles
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_140.jpg
# possible_answers:  O BGA paly & chief ch. fess dancetty<|>G E lion cr.<|>X A GB per fess & 3 cinquefoils<|>E GO chevron ch. 3 cinquefoils<|>O BGO paly & chief ch. buckle
# result_id:  1  -- selected label:  O BGA paly & chief ch. fess dancetty
# result_id:  5  -- selected label:  O BGO paly & chief ch. buckle
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_141.jpg
# possible_answers:  A S barruly<|>A S 3 lozenges (2:1)<|>G A fretty<|>A G chief<|> bendy of 4; per fess & lion cch; =; =   {OG, GA}
# result_id:  1  -- selected label:  A S barruly
# result_id:  2  -- selected label:  A S 3 lozenges (2:1)
# result_id:  4  -- selected label:  A G chief
# result_id:  3  -- selected label:  G A fretty
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_156.jpg
# possible_answers:  B OG 3 fleurs-de-lis & border
# result_id:  1  -- selected label:  B OG 3 fleurs-de-lis & border
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_158.jpg
# possible_answers:  B OAG semy of fleurs-de-lis acc. lion in chf dx & border
# result_id:  1  -- selected label:  B OAG semy of fleurs-de-lis acc. lion in chf dx & border
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_161.jpg
# possible_answers:  B OGA semy of fleurs-de-lis & bend ch. 3 lions
# result_id:  1  -- selected label:  B OGA semy of fleurs-de-lis & bend ch. 3 lions
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_164.jpg
# possible_answers:  O GAB cross ch. 5 escallops acc. 16 eagles
# result_id:  1  -- selected label:  O GAB cross ch. 5 escallops acc. 16 eagles
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_169.jpg
# possible_answers:  G X AB chief checky<|> lion, bendy; =; =   {SO, OG}<|>O G eagle
# result_id:  2  -- selected label:   lion, bendy; =; =   {SO, OG}
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_170.jpg
# possible_answers:  O GAB cross ch. 5 escallops acc. 16 eagles<|>O GB barry undy & border<|>O G 6 lions (3:2:1)<|>B AO escutcheon acc. orle of cross crosslets<|>A SG cross moline acc. 3 escallops
# result_id:  1  -- selected label:  O GAB cross ch. 5 escallops acc. 16 eagles
# result_id:  3  -- selected label:  O G 6 lions (3:2:1)
# result_id:  5  -- selected label:  A SG cross moline acc. 3 escallops
# result_id:  4  -- selected label:  B AO escutcheon acc. orle of cross crosslets
# result_id:  2  -- selected label:  O GB barry undy & border
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_171.jpg
# possible_answers:  G O cross moline<|>O G chief<|>A S 3 marmites<|>A S fess<|>B O 3 blackbirds
# result_id:  1  -- selected label:  G O cross moline
# result_id:  2  -- selected label:  O G chief
# result_id:  3  -- selected label:  A S 3 marmites
# result_id:  5  -- selected label:  B O 3 blackbirds
# result_id:  4  -- selected label:  A S fess
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_172.jpg
# possible_answers:  E G pily-barry<|>O G 3 butterflies<|>A S 2 bars gemel<|>A GSA paly & border roundely<|> 3 bars; 3 spearheads; =; =   {GO, AG}
# result_id:  2  -- selected label:  O G 3 butterflies
# result_id:  3  -- selected label:  A S 2 bars gemel
# result_id:  4  -- selected label:  A GSA paly & border roundely
# result_id:  5  -- selected label:   3 bars; 3 spearheads; =; =   {GO, AG}
# result_id:  1  -- selected label:  E G pily-barry
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_173.jpg
# possible_answers:  O G paly<|>O G barry undy<|>A G bend<|>A G eagle doubleheaded<|>E G fretty
# result_id:  3  -- selected label:  A G bend
# result_id:  4  -- selected label:  A G eagle doubleheaded
# result_id:  1  -- selected label:  O G paly
# result_id:  2  -- selected label:  O G barry undy
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_176.jpg
# possible_answers:  A G cross<|>S OG 3 ermine spots & border<|>O BG qtly & label<|>B O 2 bars
# result_id:  1  -- selected label:  A G cross
# result_id:  2  -- selected label:  S OG 3 ermine spots & border
# -----
# image: images/BnF. Departement des manuscrits. Francais 4985_177.jpg
# possible_answers:  G O 3 mallets<|>G AS bend betw 6 cross crosslets<|>S A escutcheon<|>G S fretty<|>G O bend
# result_id:  5  -- selected label:  G O bend
# result_id:  3  -- selected label:  S A escutcheon
# result_id:  1  -- selected label:  G O 3 mallets
# result_id:  4  -- selected label:  G S fretty
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-3e0b6585d0c5> in <module>
#       5         print('possible_answers: ',task['possible_answers'])
#       6         for label_result in task['selected_labels']:
# ----> 7             print('result_id: ',label_result['result_id'], ' -- selected label: ', label_result['coa_description'])
#       8
#       9         print('-----')
#
# KeyError: 'result_id'

# %%
df = pd.read_json('dataset/2021-03-17_classification-labeling-results.json')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   task_id           720 non-null    int64
#  1   image             720 non-null    object
#  2   annotations       720 non-null    object
#  3   possible_answers  720 non-null    object
#  4   selected_labels   720 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 28.2+ KB

# %%
# https://towardsdatascience.com/how-to-convert-json-into-a-pandas-dataframe-100b2ae1e0d8
# Flatten data
df_nested_list = pd.json_normalize(data)
df_nested_list
# Out:
#      task_id                                              image  \
# 0       1693  images/Donaueschinger Wappenbuch - Cod Donaues...
# 1       1694  images/Donaueschinger Wappenbuch - Cod Donaues...
# 2       1695  images/Donaueschinger Wappenbuch - Cod Donaues...
# 3       1696  images/Donaueschinger Wappenbuch - Cod Donaues...
# 4       1697  images/Donaueschinger Wappenbuch - Cod Donaues...
# ..       ...                                                ...
# 715     4226  images/BnF. Departement des manuscrits. Franca...
# 716     4227  images/BnF. Departement des manuscrits. Franca...
# 717     4228  images/BnF. Departement des manuscrits. Franca...
# 718     4229  images/BnF. Departement des manuscrits. Franca...
# 719     4230  images/BnF. Departement des manuscrits. Franca...
#
#                                            annotations  \
# 0    images/Donaueschinger Wappenbuch - Cod Donaues...
# 1    images/Donaueschinger Wappenbuch - Cod Donaues...
# 2    images/Donaueschinger Wappenbuch - Cod Donaues...
# 3    images/Donaueschinger Wappenbuch - Cod Donaues...
# 4    images/Donaueschinger Wappenbuch - Cod Donaues...
# ..                                                 ...
# 715  images/BnF. Departement des manuscrits. Franca...
# 716  images/BnF. Departement des manuscrits. Franca...
# 717  images/BnF. Departement des manuscrits. Franca...
# 718  images/BnF. Departement des manuscrits. Franca...
# 719  images/BnF. Departement des manuscrits. Franca...
#
#                                       possible_answers  \
# 0    B O cross potenty fitchy<|> eagle :dim: semy o...
# 1    O G rose<|>G A 3 hares salient<|> lion; 2 bars...
# 2    B AOG elephant bearing tower above crown in ba...
# 3                                  B O 3 fleurs-de-lis
# 4     castle; lion; =; =  {GO, AP}<|>O G 4 pales<|>...
# ..                                                 ...
# 715  O GG fess betw 2 chevrons<|>S A lion rampant<|...
# 716  G O 10 mascles<|>S GO bend betw 6 lions<|>G AA...
# 717  B OO chevron betw 3 cups covered<|>E G canton<...
# 718   barry nebuly; lion, flory; =; =   {OG, BAA}<|...
# 719   3 pales undy; bendy; =; =  {GO, AG}<|>O GZ pa...
#
#                                        selected_labels
# 0    [{'result_id': '1', 'coa_description': 'B O cr...
# 1    [{'result_id': '3', 'coa_description': ' lion;...
# 2    [{'result_id': '1', 'coa_description': 'B AOG ...
# 3    [{'result_id': '1', 'coa_description': 'B O 3 ...
# 4    [{'result_id': '1', 'coa_description': ' castl...
# ..                                                 ...
# 715  [{'result_id': '1', 'coa_description': 'O GG f...
# 716  [{'result_id': '5', 'coa_description': 'O B 3 ...
# 717  [{'result_id': '1', 'coa_description': 'B OO c...
# 718  [{'result_id': '1', 'coa_description': ' barry...
# 719  [{'result_id': '1', 'coa_description': ' 3 pal...
#
# [720 rows x 5 columns]

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

def plot_bar_chart(data):
    labels, values = zip(*data)
    indexes = np.arange(len(labels))
    width = 0.5

    plt.rcParams["figure.figsize"] = (20, 10)
    plt.bar(indexes, values, width)
    plt.xticks(indexes, labels, rotation='vertical')
    plt.show()

possible_answers = df.filter(['possible_answers']).values.reshape(1, -1).ravel().tolist()
all_answers = []
labels = []
refined_answers = []
for possible_answer in possible_answers:
    chunks = possible_answer.split('<|>')
    for c in chunks:
        all_answers.append(c)
        refined_answers.append(re.sub(r"\b[a-zA-Z]\b", "", c).lstrip().rstrip())
        ws = re.findall(r'\w+', c)
        for w in ws:
            labels.append(w)

print('all answers: ',len(all_answers))
print('all refined answers: ',len(refined_answers))
print('all single labels: ',len(labels))
# Out:
# all answers:  3001
# all refined answers:  3001
# all single labels:  15520

# %%
x = Counter(all_answers)
plot_bar_chart(x.most_common(30))
x.most_common(100)
# Out:
# [('- CREST only', 48),
#  ('- ILLEGIBLE', 33),
#  ('O G lion rampant', 22),
#  ('- TEMP', 18),
#  ('A G lion rampant', 17),
#  ('G A pale', 9),
#  ('O B lion rampant', 9),
#  ('O G eagle', 8),
#  ('O S 3 antlers in pale', 8),
#  ('B A lion cr.', 8),
#  ('G A fess', 8),
#  ('G A fess dancetty', 8),
#  ('G A bend', 8),
#  ('A G chief', 8),
#  ('G O eagle', 8),
#  ('O S lion rampant', 7),
#  ('A G gonfanon', 7),
#  ('G O bend', 7),
#  ('B O cross', 7),
#  ('G A lion rampant', 7),
#  ('A G lozengy', 7),
#  ('G E chevron', 6),
#  ('A G bendy of 4', 6),
#  ('O G paly', 6),
#  ('G A castle', 6),
#  ('G A eagle', 6),
#  ('B A unicorn salient', 6),
#  ('G Z bend', 6),
#  ('O G fess dancetty', 6),
#  ('A G cross moline', 6),
#  ('G O 2 lions passt guard', 6),
#  ('S A chevron', 6),
#  ('O G chief', 6),
#  ('G O lion rampant', 6),
#  ('S O 2 lions passt guard', 6),
#  ('O B barry', 6),
#  (' blank shield', 6),
#  ('A B chief', 5),
#  ('S A fess', 5),
#  ('A G fess', 5),
#  ('S A griffin segreant', 5),
#  ('A S 3 bars', 5),
#  ('A G bend', 5),
#  ('O S bend', 5),
#  ('S O bend', 5),
#  ('A G checky', 5),
#  ('O G qtly', 5),
#  ('A S chevron', 5),
#  ('O GA chief ch. mullet', 5),
#  ('V O chief', 5),
#  ('O G lozengy', 5),
#  ('A S barruly', 5),
#  ('G O 2 barbels addorsed', 5),
#  ('O G 4 pales', 4),
#  ('A G pily-barry', 4),
#  ('O BG bendy & border engrailed', 4),
#  ('A G per saltire', 4),
#  ('O GV doe on terrace', 4),
#  ('G A chief', 4),
#  ('G A heron stat', 4),
#  ('O SA chief ch. mullet', 4),
#  ('A G per fess & paly cch', 4),
#  ('O S per pale', 4),
#  ('G A rose', 4),
#  ('X G BA per fess & lion', 4),
#  ('A G per pale & wheel cch', 4),
#  ('G AS tierced per chevron', 4),
#  ('A G paly of 4', 4),
#  ('A G per pale & fess cch', 4),
#  ('A G chief embattled', 4),
#  ('A GO tierced per fess', 4),
#  ('O SV boar on mount', 4),
#  ('A S fess', 4),
#  ('A GG falcon rising from saltire in base', 4),
#  ('S O barry of 4', 4),
#  ('A GO chief indented ch. lion passt guard', 4),
#  ('G O stirrup', 4),
#  ('B O eagle', 4),
#  ('A G 2 talons in saltire', 4),
#  ('G A 2 wings', 4),
#  ('G A ibex segreant', 4),
#  ('G A pily-barry', 4),
#  ('A B paly', 4),
#  ('A S bend', 4),
#  ('G O 3 mallets', 4),
#  ('A S ibex horn', 4),
#  ('O GBA 4 pales & canton ch. mullet', 4),
#  ('G AO 3 waterlily leaves inv & chief', 4),
#  ('A G lion q.f. cr.', 4),
#  ('A G roundelly', 4),
#  (' ps[eagle, paly of 4   {AG, OG}]', 4),
#  ('B A cross', 4),
#  ('G AO rose & border', 4),
#  ('O G bend', 4),
#  ('O S eagle per fess', 4),
#  ('O B per bend', 4),
#  ('O S lion naissant', 4),
#  ('B AA 2 bars & chief', 4),
#  ('A G 3 chevrons', 4),
#  ('O G saltire', 4)]

# %%
#  rule based generation 
# colors -> different objects > a modified object (regarding to poses) ( location to each other is injected in between )

y = Counter(labels)
plot_bar_chart(y.most_common(30))
y.most_common(100)
# Out:
# [('A', 1248),
#  ('G', 1181),
#  ('O', 869),
#  ('3', 553),
#  ('S', 500),
#  ('B', 480),
#  ('lion', 368),
#  ('bend', 318),
#  ('per', 317),
#  ('2', 289),
#  ('fess', 260),
#  ('ch', 246),
#  ('pale', 223),
#  ('chief', 223),
#  ('in', 190),
#  ('of', 176),
#  ('cross', 153),
#  ('AG', 149),
#  ('border', 144),
#  ('acc', 139),
#  ('eagle', 133),
#  ('X', 128),
#  ('de', 114),
#  ('lis', 114),
#  ('fleurs', 104),
#  ('rampant', 103),
#  ('chevron', 103),
#  ('barry', 101),
#  ('GA', 100),
#  ('s', 100),
#  ('saltire', 93),
#  ('GO', 90),
#  ('passt', 90),
#  ('cr', 89),
#  ('OG', 85),
#  ('lions', 84),
#  ('AO', 78),
#  ('bendy', 77),
#  ('E', 73),
#  ('4', 71),
#  ('checky', 71),
#  ('AS', 71),
#  ('betw', 69),
#  ('semy', 67),
#  ('bars', 63),
#  ('addorsed', 61),
#  ('guard', 60),
#  ('AB', 59),
#  ('head', 57),
#  ('cch', 57),
#  ('paly', 55),
#  ('OS', 51),
#  ('OO', 51),
#  ('6', 50),
#  ('chf', 48),
#  ('CREST', 48),
#  ('only', 48),
#  ('isst', 47),
#  ('mount', 45),
#  ('OB', 45),
#  ('BO', 44),
#  ('label', 43),
#  ('on', 42),
#  ('V', 41),
#  ('plain', 41),
#  ('GG', 41),
#  ('engrailed', 40),
#  ('lozenges', 40),
#  ('SA', 40),
#  ('lozengy', 40),
#  ('rose', 39),
#  ('5', 39),
#  ('dancetty', 39),
#  ('barruly', 38),
#  ('mullet', 38),
#  ('chevrons', 38),
#  ('AA', 38),
#  ('ibex', 38),
#  ('BA', 37),
#  ('pales', 36),
#  ('crusily', 36),
#  ('flory', 36),
#  ('roundels', 36),
#  ('OA', 35),
#  ('sn', 33),
#  ('crescents', 33),
#  ('ILLEGIBLE', 33),
#  ('1', 33),
#  ('SG', 33),
#  ('undy', 33),
#  ('holding', 32),
#  ('escallops', 31),
#  ('BG', 30),
#  ('qtly', 30),
#  ('compony', 29),
#  ('SO', 29),
#  ('GS', 29),
#  ('griffin', 28),
#  ('with', 28),
#  ('inv', 28)]

# %%
cleaned_labels = [l for l in labels if len(l)>2]
z = Counter(cleaned_labels)
plot_bar_chart(z.most_common(30))
z.most_common(30)
# Out:
# [('lion', 368),
#  ('bend', 318),
#  ('per', 317),
#  ('fess', 260),
#  ('pale', 223),
#  ('chief', 223),
#  ('cross', 153),
#  ('border', 144),
#  ('acc', 139),
#  ('eagle', 133),
#  ('lis', 114),
#  ('fleurs', 104),
#  ('rampant', 103),
#  ('chevron', 103),
#  ('barry', 101),
#  ('saltire', 93),
#  ('passt', 90),
#  ('lions', 84),
#  ('bendy', 77),
#  ('checky', 71),
#  ('betw', 69),
#  ('semy', 67),
#  ('bars', 63),
#  ('addorsed', 61),
#  ('guard', 60),
#  ('head', 57),
#  ('cch', 57),
#  ('paly', 55),
#  ('chf', 48),
#  ('CREST', 48)]

# %%
x = Counter(refined_answers)
plot_bar_chart(x.most_common(30))
x.most_common(100)
# Out:
# [('lion rampant', 81),
#  ('bend', 52),
#  ('- CREST only', 48),
#  ('chief', 41),
#  ('fess', 38),
#  ('eagle', 37),
#  ('- ILLEGIBLE', 33),
#  ('lion cr.', 27),
#  ('chevron', 26),
#  ('barry', 26),
#  ('cross', 26),
#  ('per pale', 22),
#  ('fess dancetty', 19),
#  ('pale', 19),
#  ('barruly', 19),
#  ('bendy', 18),
#  ('lozengy', 18),
#  ('- TEMP', 18),
#  ('3 chevrons', 17),
#  ('qtly', 16),
#  ('3 lions', 15),
#  ('rose', 14),
#  ('pily-barry', 14),
#  ('2 lions passt guard', 14),
#  ('cross moline', 14),
#  ('paly', 13),
#  ('fretty', 13),
#  ('griffin segreant', 12),
#  ('gonfanon', 12),
#  ('per bend', 12),
#  ('checky', 12),
#  ('cross engrailed', 12),
#  ('barry of 4', 11),
#  ('ibex segreant', 11),
#  ('2 bars', 11),
#  ('vairy', 11),
#  ('saltire', 10),
#  ('3 antlers in pale', 10),
#  ('unicorn salient', 10),
#  ('2 barbels addorsed', 9),
#  ('bendy of 4', 8),
#  ('castle', 8),
#  ('2 wings', 8),
#  ('3 mallets', 8),
#  ('fleur-de-lis', 8),
#  ('3 crescents (2:1)', 8),
#  ('chief indented', 8),
#  ('barry undy', 8),
#  ('bend dancetty', 7),
#  ('canton', 7),
#  ('tower', 7),
#  ('per chevron', 7),
#  ('roundelly', 7),
#  ("ibex' head", 7),
#  ('3 fleurs-de-lis', 6),
#  ('3 bends', 6),
#  ('per saltire', 6),
#  ('pily-paly', 6),
#  ('stirrup', 6),
#  ('per pale & fess cch', 6),
#  ('ibex naissant', 6),
#  ('2 gambs in saltire', 6),
#  ('wolf rampant', 6),
#  ('chief embattled', 6),
#  ('3 lozenges in bend', 6),
#  ('3 escutcheons', 6),
#  ('gironny', 6),
#  ('eagle doubleheaded', 6),
#  ('3 cinquefoils', 6),
#  ('lion passt', 6),
#  ('billety', 6),
#  ('blank shield', 6),
#  ('3 bars', 5),
#  ('mill wheel', 5),
#  ('panther', 5),
#  ('3 eagles', 5),
#  ('GA chief ch. mullet', 5),
#  ('3 pales', 5),
#  ('plain', 5),
#  ('3 roundels', 5),
#  ('cinquefoil', 5),
#  ('escutcheon', 5),
#  ('OO lion, billety', 5),
#  ('2 lions passt', 5),
#  ('4 pales', 4),
#  ('BG bendy & border engrailed', 4),
#  ('3 lions passt guard', 4),
#  ('GV doe on terrace', 4),
#  ('heron stat', 4),
#  ('SA chief ch. mullet', 4),
#  ('per fess & paly cch', 4),
#  ('2 chicots in saltire', 4),
#  ("arrowhead palewise from bull' attire inv = Odrowaz", 4),
#  ('AO swan & border', 4),
#  ('AG chief per pale', 4),
#  ('BA per fess & lion', 4),
#  ('per pale & wheel cch', 4),
#  ('AS tierced per chevron', 4),
#  ('paly of 4', 4),
#  ('2 bends', 4)]

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('dataset/annotated-images/Donaueschinger Wappenbuch - Cod. Donaueschingen 496_119v.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# to try: https://www.analyticsvidhya.com/blog/2020/10/create-image-classification-model-python-keras/
